# %%
import pandas as pd

# %%
df=pd.read_csv('D:\\python\\Titanic_ML\GDP\\hdx-bf9db15b-1de7-4958-8f5a-0980c1f71a64\\data\\pse030_baseline_csv_2.csv')

# %%
df.head()
# Out:
#   country_code          country_name         2013          2012          2011  \
# 0          ABW                 ARUBA          NaN           NaN  36016.483757
# 1          AFG           AFGHANISTAN  1946.193806   1927.138767   1695.153436
# 2          AGO                ANGOLA  7736.174682   7360.598595   7094.084302
# 3          ALB               ALBANIA  9930.943226   9666.728238   9640.130216
# 4          ARE  UNITED ARAB EMIRATES          NaN  59845.256817  56376.769923
#
#            2010          2009          2008          2007          2006  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1   1604.191457   1497.884256   1258.739944   1222.764099   1076.461378
# 2   6904.562607   6813.103048   6821.202994   6079.390171   4996.766535
# 3   9297.492753   9345.093762   8769.117670   7659.173527   7181.094192
# 4  55764.873251  59291.103838  70133.152975  78193.619487  87766.147264
#
# ...

# %%
df.shape
# Out:
# (191, 36)

# %%
df.iloc[0,2:]
# Out:
# 2013        NaN
# 2012        NaN
# 2011    36016.5
# 2010        NaN
# 2009        NaN
# 2008        NaN
# 2007        NaN
# 2006        NaN
# 2005        NaN
# 2004        NaN
# 2003        NaN
# 2002        NaN
# 2001        NaN
# 2000        NaN
# 1999        NaN
# 1998        NaN
# 1997        NaN
# 1996        NaN
# 1995        NaN
# 1994        NaN
# 1993        NaN
# 1992        NaN
# 1991        NaN
# 1990        NaN
# 1989        NaN
# 1988        NaN
# 1987        NaN
# 1986        NaN
# 1985        NaN
# 1984        NaN
# 1983        NaN
# 1982        NaN
# 1981        NaN
# 1980        NaN
# Name: 0, dtype: object

# %%
df['2013'].isnull().value_counts()
# Out:
# False    182
# True       9
# Name: 2013, dtype: int64

# %%
df['2012'].isnull().value_counts()
# Out:
# False    188
# True       3
# Name: 2012, dtype: int64

# %%
df['2011'].isnull().value_counts()
# Out:
# False    189
# True       2
# Name: 2011, dtype: int64

# %%
df.where(pd.notna(df), df.mean(), axis='columns' )
# Out:
#     country_code                      country_name          2013  \
# 0            ABW                             ARUBA  17658.031927
# 1            AFG                       AFGHANISTAN   1946.193806
# 2            AGO                            ANGOLA   7736.174682
# 3            ALB                           ALBANIA   9930.943226
# 4            ARE              UNITED ARAB EMIRATES  17658.031927
# 5            ARG                         ARGENTINA  17658.031927
# 6            ARM                           ARMENIA   7776.286043
# 7            ATG               ANTIGUA AND BARBUDA  21027.826640
# 8            AUS                         AUSTRALIA  43202.367688
# 9            AUT                           AUSTRIA  45079.092211
# 10           AZE                        AZERBAIJAN  17143.109665
# 11           BDI                           BURUNDI    771.715430
# 12           BEL                           BELGIUM  41574.756309
# ...

# %%
df['2013'].isnull().value_counts()
# Out:
# False    182
# True       9
# Name: 2013, dtype: int64

# %%
df.head()
# Out:
#   country_code          country_name         2013          2012          2011  \
# 0          ABW                 ARUBA          NaN           NaN  36016.483757
# 1          AFG           AFGHANISTAN  1946.193806   1927.138767   1695.153436
# 2          AGO                ANGOLA  7736.174682   7360.598595   7094.084302
# 3          ALB               ALBANIA  9930.943226   9666.728238   9640.130216
# 4          ARE  UNITED ARAB EMIRATES          NaN  59845.256817  56376.769923
#
#            2010          2009          2008          2007          2006  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1   1604.191457   1497.884256   1258.739944   1222.764099   1076.461378
# 2   6904.562607   6813.103048   6821.202994   6079.390171   4996.766535
# 3   9297.492753   9345.093762   8769.117670   7659.173527   7181.094192
# 4  55764.873251  59291.103838  70133.152975  78193.619487  87766.147264
#
# ...

# %%
df.isnull().sum()
# Out:
# country_code     0
# country_name     0
# 2013             9
# 2012             3
# 2011             2
# 2010             2
# 2009             2
# 2008             2
# 2007             3
# 2006             2
# 2005             2
# 2004             3
# 2003             3
# 2002             3
# 2001             3
# 2000             4
# 1999             6
# 1998             8
# 1997             8
# 1996             8
# 1995             8
# 1994            11
# 1993            14
# 1992            16
# 1991            17
# 1990            19
# 1989            39
# 1988            41
# 1987            43
# 1986            47
# 1985            49
# 1984            54
# 1983            56
# 1982            56
# 1981            59
# 1980            63
# dtype: int64

# %%
df.fillna(df.mean())
# Out:
#     country_code                      country_name          2013  \
# 0            ABW                             ARUBA  17658.031927
# 1            AFG                       AFGHANISTAN   1946.193806
# 2            AGO                            ANGOLA   7736.174682
# 3            ALB                           ALBANIA   9930.943226
# 4            ARE              UNITED ARAB EMIRATES  17658.031927
# 5            ARG                         ARGENTINA  17658.031927
# 6            ARM                           ARMENIA   7776.286043
# 7            ATG               ANTIGUA AND BARBUDA  21027.826640
# 8            AUS                         AUSTRALIA  43202.367688
# 9            AUT                           AUSTRIA  45079.092211
# 10           AZE                        AZERBAIJAN  17143.109665
# 11           BDI                           BURUNDI    771.715430
# 12           BEL                           BELGIUM  41574.756309
# ...

# %%
df.isnull().sum()
# Out:
# country_code     0
# country_name     0
# 2013             9
# 2012             3
# 2011             2
# 2010             2
# 2009             2
# 2008             2
# 2007             3
# 2006             2
# 2005             2
# 2004             3
# 2003             3
# 2002             3
# 2001             3
# 2000             4
# 1999             6
# 1998             8
# 1997             8
# 1996             8
# 1995             8
# 1994            11
# 1993            14
# 1992            16
# 1991            17
# 1990            19
# 1989            39
# 1988            41
# 1987            43
# 1986            47
# 1985            49
# 1984            54
# 1983            56
# 1982            56
# 1981            59
# 1980            63
# dtype: int64

# %%
df.head()
# Out:
#   country_code          country_name         2013          2012          2011  \
# 0          ABW                 ARUBA          NaN           NaN  36016.483757
# 1          AFG           AFGHANISTAN  1946.193806   1927.138767   1695.153436
# 2          AGO                ANGOLA  7736.174682   7360.598595   7094.084302
# 3          ALB               ALBANIA  9930.943226   9666.728238   9640.130216
# 4          ARE  UNITED ARAB EMIRATES          NaN  59845.256817  56376.769923
#
#            2010          2009          2008          2007          2006  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1   1604.191457   1497.884256   1258.739944   1222.764099   1076.461378
# 2   6904.562607   6813.103048   6821.202994   6079.390171   4996.766535
# 3   9297.492753   9345.093762   8769.117670   7659.173527   7181.094192
# 4  55764.873251  59291.103838  70133.152975  78193.619487  87766.147264
#
# ...

# %%
df['2013'].fillna(df.mean(), inplace=True)

# %%
df['2013']
# Out:
# 0               NaN
# 1       1946.193806
# 2       7736.174682
# 3       9930.943226
# 4               NaN
# 5               NaN
# 6       7776.286043
# 7      21027.826640
# 8      43202.367688
# 9      45079.092211
# 10     17143.109665
# 11       771.715430
# 12     41574.756309
# 13      1790.753637
# 14      1684.479651
# 15      2948.014890
# 16     15731.672624
# 17     43850.939718
# 18     23264.272211
# 19      9535.539791
# 20     17619.769656
# 21      8486.898540
# 22              NaN
# 23      6131.061689
# 24     15037.457469
# 25              NaN
# 26     71776.648012
# 27      7404.736784
# 28     15751.902206
# 29       603.742960
#            ...
# 161    44658.231787
# 162     6685.338117
# 163    24587.485595
# 164             NaN
# 165     2088.591836
# 166     1390.519711
# 167    14393.530704
# 168     2512.247566
# 169    14004.160057
# 170     2241.887680
# 171     5304.206689
# 172    30446.007539
# 173    11124.496009
# 174    18782.845752
# ...

# %%
df.describe()
# Out:
#                 2013           2012           2011           2010  \
# count     182.000000     188.000000     189.000000     189.000000
# mean    17658.031927   17857.793697   17484.789817   16574.202002
# std     20999.163749   21052.006802   20467.703935   19153.242771
# min       603.742960     750.101696     712.009424     671.009525
# 25%      3378.390824    3594.537999    3504.748159    3269.671085
# 50%     10989.600152   10839.327444   10534.605654   10165.203395
# 75%     23601.930281   23538.246622   22570.499411   21082.890063
# max    142599.240319  134289.773572  133733.867707  126613.791256
#
#                 2009           2008           2007           2006  \
# count     189.000000     189.000000     188.000000     189.000000
# mean    15991.188352   16408.817099   15873.682335   14946.752296
# std     18285.911247   19134.285528   18888.866495   18256.274958
# min       622.168303     564.602261     522.540718     457.822768
# ...

# %%
df['2013'].fillna(df['2013'].mean(), inplace=True)

# %%
df['2012'].fillna(df['2012'].mean(), inplace=True)
df['2011'].fillna(df['2011'].mean(), inplace=True)

# %%
df['2011'].isnull().value_counts()
# Out:
# False    191
# Name: 2011, dtype: int64

# %%
df['2010'].fillna(df['2010'].mean(), inplace=True)

# %%
df['2010']
# Out:
# 0      16574.202002
# 1       1604.191457
# 2       6904.562607
# 3       9297.492753
# 4      55764.873251
# 5      16574.202002
# 6       6376.326219
# 7      20151.493171
# 8      39086.327232
# 9      41804.223061
# 10     15627.747776
# 11       710.628836
# 12     39211.336579
# 13      1603.462930
# 14      1404.537166
# 15      2409.548511
# 16     14690.492141
# 17     39732.909485
# 18     22468.542211
# 19      8746.080609
# 20     15385.599226
# 21      8042.980224
# 22     55254.716736
# 23      5172.147977
# 24     13759.420066
# 25     15025.026884
# 26     69208.221059
# 27      6383.762699
# 28     13079.288876
# 29       882.904458
#            ...
# 161    41727.176120
# 162     6379.988416
# 163    19831.577577
# 164     4996.331466
# 165     1913.050960
# 166     1220.821967
# 167    12562.432667
# 168     2067.619449
# 169     9828.807554
# 170     1741.196171
# 171     4880.890286
# 172    28728.157192
# 173    10200.397987
# 174    16193.371514
# ...

# %%
df.fillna(df.mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# country_code    0
# country_name    0
# 2013            0
# 2012            0
# 2011            0
# 2010            0
# 2009            0
# 2008            0
# 2007            0
# 2006            0
# 2005            0
# 2004            0
# 2003            0
# 2002            0
# 2001            0
# 2000            0
# 1999            0
# 1998            0
# 1997            0
# 1996            0
# 1995            0
# 1994            0
# 1993            0
# 1992            0
# 1991            0
# 1990            0
# 1989            0
# 1988            0
# 1987            0
# 1986            0
# 1985            0
# 1984            0
# 1983            0
# 1982            0
# 1981            0
# 1980            0
# dtype: int64

# %%
df['1983'].isnull().value_counts()
# Out:
# False    191
# Name: 1983, dtype: int64

# %%
df.describe()
# Out:
#                 2013           2012           2011           2010  \
# count     191.000000     191.000000     191.000000     191.000000
# mean    17658.031927   17857.793697   17484.789817   16574.202002
# std     20495.781716   20885.145465   20359.694190   19052.169545
# min       603.742960     750.101696     712.009424     671.009525
# 25%      3773.077620    3671.351516    3507.511567    3325.365379
# 50%     11656.742836   10950.004194   10628.747318   10200.397987
# 75%     23299.295819   23343.056590   22547.165061   20881.859946
# max    142599.240319  134289.773572  133733.867707  126613.791256
#
#                 2009           2008           2007           2006  \
# count     191.000000     191.000000     191.000000     191.000000
# mean    15991.188352   16408.817099   15873.682335   14946.752296
# std     18189.415000   19033.312340   18739.150529   18159.935103
# min       622.168303     564.602261     522.540718     457.822768
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 0 to 190
# Data columns (total 36 columns):
# country_code    191 non-null object
# country_name    191 non-null object
# 2013            191 non-null float64
# 2012            191 non-null float64
# 2011            191 non-null float64
# 2010            191 non-null float64
# 2009            191 non-null float64
# 2008            191 non-null float64
# 2007            191 non-null float64
# 2006            191 non-null float64
# 2005            191 non-null float64
# 2004            191 non-null float64
# 2003            191 non-null float64
# 2002            191 non-null float64
# 2001            191 non-null float64
# 2000            191 non-null float64
# 1999            191 non-null float64
# 1998            191 non-null float64
# 1997            191 non-null float64
# 1996            191 non-null float64
# 1995            191 non-null float64
# 1994            191 non-null float64
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='darkgrid')

# %%
sns.distplot(df['2013'], bins=10, color='r')
sns.distplot(df['2012'], bins=10, color='b')
# Out:
# C:\Users\rabis\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\rabis\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
df.country_code.max()
# Out:
# 'ZWE'

# %%
x=df['2013'].mean()
y=df['2013'].min()
z=df['2013'].max()

# %%
x
# Out:
# 17658.031926744472

# %%
y
# Out:
# 603.742959794015

# %%
z
# Out:
# 142599.240319212

# %%
plt.figure(figsize=(15,8))
plt.scatter(df['2013'], df['2013'])
plt.plot()
plt.show()

# %%
plt.figure(figsize=(15,8))

plt.hist(df['2013'], bins=10)
plt.plot()
# Out:
# []

# %%
df.sample(10)
# Out:
#     country_code          country_name          2013          2012  \
# 67           GNB         GUINEA-BISSAU   1407.026772   1415.660482
# 136          PHL           PHILIPPINES   6535.875864   6113.369459
# 169          TKM          TURKMENISTAN  14004.160057  12684.257949
# 86           JAM               JAMAICA   8892.762804   8674.215822
# 83           ISL               ICELAND  41859.185786  40464.095814
# 129          NOR                NORWAY  64405.712221  65103.698037
# 4            ARE  UNITED ARAB EMIRATES  17658.031927  59845.256817
# 99           LBR               LIBERIA    877.995480    796.465151
# 163          SYC            SEYCHELLES  24587.485595  23239.589313
# 184          VNM              VIET NAM   5294.439869   5000.712149
#
#              2011          2010          2009          2008          2007  \
# 67    1456.847769   1340.217195   1296.994838   1273.474769   1237.146187
# 136   5720.684467   5500.237200   5133.913518   5120.366741   4904.326170
# ...

# %%
df[['country_name', '2013']].max()
# Out:
# country_name    ZIMBABWE
# 2013              142599
# dtype: object

# %%
df[['2010', '2011']].max()
# Out:
# 2010    126613.791256
# 2011    133733.867707
# dtype: float64

# %%
plt.figure(figsize=(15,8))
plt.scatter( x, df['2013'].head(20), linewidths=6, marker=".")
plt.scatter(x, df['2012'].head(20), linewidths=6, marker="^")
plt.scatter(x, df['2011'].head(20), marker='o' , linewidths=6)
plt.scatter(x, df['2010'].head(20) , marker='v' , linewidths=6)

plt.xlabel("country_code")
plt.ylabel("2013, 2012,2011, 2010")
plt.legend()
plt.plot()
plt.show()

# %%
x=df.country_code.head(20)

# %%
x=df.country_code.iloc[20:40]

# %%
plt.figure(figsize=(15,8))
plt.scatter( x, df['2013'].head(20), linewidths=6, marker=".")
plt.scatter(x, df['2012'].head(20), linewidths=6, marker="^")
plt.scatter(x, df['2011'].head(20), marker='o' , linewidths=6)
plt.scatter(x, df['2010'].head(20) , marker='v' , linewidths=6)

plt.xlabel("country_code")
plt.ylabel("2013, 2012,2011, 2010")
plt.legend()
plt.plot()
plt.show()

# %%
x=df.country_code.iloc[40:60]

# %%
plt.figure(figsize=(15,8))
plt.scatter( x, df['2013'].head(20), linewidths=6, marker=".")
plt.scatter(x, df['2012'].head(20), linewidths=6, marker="^")
plt.scatter(x, df['2011'].head(20), marker='o' , linewidths=6)
plt.scatter(x, df['2010'].head(20) , marker='v' , linewidths=6)

plt.xlabel("country_code")
plt.ylabel("2013, 2012,2011, 2010")
plt.legend()
plt.plot()
plt.show()

# %%
x=df.country_code.iloc[60:80]

# %%
plt.figure(figsize=(15,8))
plt.scatter( x, df['2013'].head(20), linewidths=6, marker=".")
plt.scatter(x, df['2012'].head(20), linewidths=6, marker="^")
plt.scatter(x, df['2011'].head(20), marker='o' , linewidths=6)
plt.scatter(x, df['2010'].head(20) , marker='v' , linewidths=6)

plt.xlabel("country_code")
plt.ylabel("2013, 2012,2011, 2010")
plt.legend()
plt.plot()
plt.show()

# %%
x=df.country_code.iloc[80:100]

# %%
plt.figure(figsize=(15,8))
plt.scatter( x, df['2013'].head(20), linewidths=6, marker=".")
plt.scatter(x, df['2012'].head(20), linewidths=6, marker="^")
plt.scatter(x, df['2011'].head(20), marker='o' , linewidths=6)
plt.scatter(x, df['2010'].head(20) , marker='v' , linewidths=6)

plt.xlabel("country_code")
plt.ylabel("2013, 2012,2011, 2010")
plt.legend()
plt.plot()
plt.show()

# %%
x=df.country_code.iloc[100:120]

# %%
plt.figure(figsize=(15,8))
plt.scatter( x, df['2013'].head(20), linewidths=6, marker=".")
plt.scatter(x, df['2012'].head(20), linewidths=6, marker="^")
plt.scatter(x, df['2011'].head(20), marker='o' , linewidths=6)
plt.scatter(x, df['2010'].head(20) , marker='v' , linewidths=6)

plt.xlabel("country_code")
plt.ylabel("2013, 2012,2011, 2010")
plt.legend()
plt.plot()
plt.show()

# %%
x=df.country_code.iloc[120:140]

# %%
plt.figure(figsize=(15,8))
plt.scatter( x, df['2013'].head(20), linewidths=6, marker=".")
plt.scatter(x, df['2012'].head(20), linewidths=6, marker="^")
plt.scatter(x, df['2011'].head(20), marker='o' , linewidths=6)
plt.scatter(x, df['2010'].head(20) , marker='v' , linewidths=6)

plt.xlabel("country_code")
plt.ylabel("2013, 2012,2011, 2010")
plt.legend()
plt.plot()
plt.show()

# %%
x=df.country_code.iloc[140:160]

# %%
plt.figure(figsize=(15,8))
plt.scatter( x, df['2013'].head(20), linewidths=6, marker=".")
plt.scatter(x, df['2012'].head(20), linewidths=6, marker="^")
plt.scatter(x, df['2011'].head(20), marker='o' , linewidths=6)
plt.scatter(x, df['2010'].head(20) , marker='v' , linewidths=6)

plt.xlabel("country_code")
plt.ylabel("2013, 2012,2011, 2010")
plt.legend()
plt.plot()
plt.show()

# %%
x=df.country_code.iloc[160:180]

# %%
plt.figure(figsize=(15,8))
plt.scatter( x, df['2013'].head(20), linewidths=6, marker=".")
plt.scatter(x, df['2012'].head(20), linewidths=6, marker="^")
plt.scatter(x, df['2011'].head(20), marker='o' , linewidths=6)
plt.scatter(x, df['2010'].head(20) , marker='v' , linewidths=6)

plt.xlabel("country_code")
plt.ylabel("2013, 2012,2011, 2010")
plt.legend()
plt.plot()
plt.show()
